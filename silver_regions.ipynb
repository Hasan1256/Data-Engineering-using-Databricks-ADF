# %%
df=spark.read.table("project1_catalog.bronze.regions")

# %%
df.display()

# %%
df = df.drop("_rescued_data")

# %%
df.write.format("delta").mode("overwrite").save("abfss://silver@project1ds.dfs.core.windows.net/regions")

# %%
# %sql
create table if not exists project1_catalog.silver.regions_silver
using delta
location "abfss://silver@project1ds.dfs.core.windows.net/regions"

# %%
# %sql
select * from project1_catalog.silver.regions_silver;
