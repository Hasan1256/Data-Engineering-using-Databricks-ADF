# %%
datasets= [
    {
        "file_name":"products"
    },
    {
        "file_name":"customers"
    },
    {
        "file_name":"orders"
    }
]

# %%
dbutils.jobs.taskValues.set("output_datasets",datasets)
