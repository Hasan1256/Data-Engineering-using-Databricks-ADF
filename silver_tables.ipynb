# %%
df_regions = spark.read.format("delta").load("abfss://silver@project1ds.dfs.core.windows.net/orders")

# %%
df_regions.display()

# %%
# %sql
SELECT *
FROM delta.`abfss://silver@project1ds.dfs.core.windows.net/products`;
